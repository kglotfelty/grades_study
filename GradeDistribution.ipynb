# %% [markdown]
# # ACIS Grade Branching Ratios
#
# As part of the understanding of the MARX PSF disucssion we have come to understand that MARX does not currently simulate the correct ratio of ACIS grades.  The ACIS grades are used as part of the EDSER subpixel algorithm to reposition events within a pixel.  If the grade ratios are incorrect, then the locations will not match what is observed resulting in a PSF that doesn't match the observations.
#
# In this analysis we show the results of looking at the true branching ratios for the FI and the BI devices.
#
# Realistically, just about any observations could be used as the branching ratios are not senstive to
# the type of source.  But to quell any concerns we have elected to use one of the calibration targets, Abell 1795, which is a large cluster that fills multiple chips so provides lots of data.

# %% [markdown]
# ## Download the data
#
# Start CIAO (change for your own CIAO instation)

# %%
source /export/ciao/bin/ciao.bash
# Out:
# CIAO configuration is complete...
# CIAO 4.8 Thursday, January 28, 2016
#   bindir      : /export/ciao-4.8/bin
#   CALDB       : 4.7.1

# %% [markdown]
# Now we look for all the Abell 1795 observations.  We don't care about time/etc since we're going to be looking at the data on a per-chip basis.

# %%
find_chandra_obsid a1795 inst=acis grat=none detail=obsid | tee obsis.lis
# Out:
# # obsid
# 493
# 494
# 3666
# 5286
# 5287
# 5288
# 5289
# 5290
# 6159
# 6160
# 6161
# 6162
# 6163
# 10898
# 10899
# 10900
# 10901
# 12026
# 12027
# 12028
# 12029
# 13106
# 13107
# 13108
# 13109
# 13110
# 13111
# 13112
# 13113
# 13412
# 13413
# 13414
# 13415
# 13416
# 13417
# 14268
# 14269
# 14270
# 14271
# 14272
# 14273
# 14274
# 14275
# 15485
# 15486
# 15487
# 15488
# 15489
# 15490
# 15491
# 15492
# 16432
# 16433
# 16434
# 16435
# 16436
# 16437
# 16438
# 16439
# 16465
# 16466
# 16467
# 16468
# 16469
# 16470
# 16471
# 16472
# 17397
# 17398
# 17399
# 17400
# 17401
# 17402
# 17403
# 17404
# 17405
# 17406
# 17407
# 17408
# 17409
# 17410
# 17411
# 17683
# 17684
# 17685
# 17686
# 18423
# 18424

# %% [markdown]
# We only need the Level 2 event files.

# %%
download_chandra_obsid @obsis.lis evt2
# Out:
# Downloading files for ObsId 493, total size is 19 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       19 Mb    already downloaded
#
# Downloading files for ObsId 494, total size is 16 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       16 Mb    already downloaded
#
# Downloading files for ObsId 3666, total size is 10 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       10 Mb    already downloaded
#
# Downloading files for ObsId 5286, total size is 8 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        8 Mb    already downloaded
#
# Downloading files for ObsId 5287, total size is 10 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       10 Mb    already downloaded
#
# Downloading files for ObsId 5288, total size is 10 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       10 Mb    already downloaded
#
# Downloading files for ObsId 5289, total size is 7 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        7 Mb    already downloaded
#
# Downloading files for ObsId 5290, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 6159, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 6160, total size is 11 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       11 Mb    already downloaded
#
# Downloading files for ObsId 6161, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 6162, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 6163, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 10898, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 10899, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 10900, total size is 14 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       14 Mb    already downloaded
#
# Downloading files for ObsId 10901, total size is 10 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       10 Mb    already downloaded
#
# Downloading files for ObsId 12026, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 12027, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 12028, total size is 12 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       12 Mb    already downloaded
#
# Downloading files for ObsId 12029, total size is 11 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       11 Mb    already downloaded
#
# Downloading files for ObsId 13106, total size is 8 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        8 Mb    already downloaded
#
# Downloading files for ObsId 13107, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 13108, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 13109, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 13110, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13111, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13112, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 13113, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13412, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13413, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 13414, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13415, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 13416, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 13417, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 14268, total size is 7 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        7 Mb    already downloaded
#
# Downloading files for ObsId 14269, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 14270, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 14271, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 14272, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 14273, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 14274, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 14275, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 15485, total size is 7 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        7 Mb    already downloaded
#
# Downloading files for ObsId 15486, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 15487, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 15488, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 15489, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 15490, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 15491, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 15492, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16432, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 16433, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 16434, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 16435, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16436, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16437, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16438, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 16439, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16465, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 16466, total size is 7 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        7 Mb    already downloaded
#
# Downloading files for ObsId 16467, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16468, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16469, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 16470, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 16471, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 16472, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17397, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 17398, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 17399, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 17400, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 17401, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17402, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17403, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 17404, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17405, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 17406, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17407, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17408, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17409, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 17410, total size is 4 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        4 Mb    already downloaded
#
# Downloading files for ObsId 17411, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 17683, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 17684, total size is 3 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        3 Mb    already downloaded
#
# Downloading files for ObsId 17685, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 17686, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded
#
# Downloading files for ObsId 18423, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        6 Mb    already downloaded
#
# Downloading files for ObsId 18424, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        5 Mb    already downloaded

# %% [markdown]
# ## Combine Data
#
# For this analysis we don't care what data are actually on any particular chip.  The event grades don't _care_ what source they came from -- just their energy.
#
# Because the FI and BI chips are different, the distribution of grades are different.
#
# We combine all the event file together for FI and separately for the BI chip, only keeping a selection of columns.
#
# The `[subpace -stuff]` are there to avoid a messy subspace in the output file (many, many GTIs) and the
# `lookup=""` is there to prevent a long header merge which we don't need to be correct.

# %%
dmmerge "*/primary/*evt2.fits.gz[ccd_id=0,1,2,3,4,6,8,9,status=0][cols chipx,chipy,energy,grade,fltgrade][subspace -time,-expno]" a1795_FI_fltgrades.fits clob+ look=""
dmmerge "*/primary/*evt2.fits.gz[ccd_id=5,7,status=0][cols chipx,chipy,energy,grade,fltgrade][subspace -time,-expno]" a1795_BI_fltgrades.fits clob+ look=""

# %% [markdown]
# ## Front Side
#
# We start with the data for the FI devices.
#
# First, we create an image with the grade on the X-axis, and Energy on the Y-axis.  An image is just a 2D bin which makes the other things we're going to be doing easier.  We arbitrarly selected an energy bin size of 100 eV -- as good a choice as any since we're not considering redistribution effects.
#
# We display the image below, though it's not terribly useful.

# %%
c="FI"
dmcopy "a1795_${c}_fltgrades.fits[grade=0,2,3,4,6][bin grade=0:7:1,energy=0:10000:100][opt type=i4]" ${c}.img clob+
dmimg2jpg infile=${c}.img outfile=${c}.jpg mode=h clob+ 
display < ${c}.jpg

# %% [markdown]
# Now, we want to normalize the image by the number of events in each energy bin.  We'll do this using a few DM tools.
#
# 1.  First we use dmimgproject to collapse the data onto the Y axis.  This gives us, amoung other things, the
#     total number of events vs. energy summed across all grades.
# 2.  We then extrude, reproject, those sums back along all columns in the image.  This is used to normlize the
#     previous image.
# 3.  The counts per-grade-per-energy are divided by counts-per-energy to give us fraction of counts per grade per energy
#     using dmimgcalc

# %%
dmimgproject ${c}.img ${c}.stats y clob+
dmimgreproject ${c}.stats"[cols y,sum]" ${c}.img ${c}.sum meth=close clob+
dmimgcalc ${c}.img ${c}.sum frac_${c}.img div clob+

# And now display it
dmimg2jpg infile=${c}.img outfile=${c}_norm.jpg mode=h clob+ 
display < ${c}_norm.jpg

# %% [markdown]
# Now compute an error image by simply propagating the errors.  Technically the counts and total counts are correlated so there should be a cross term, but it will be small given the number of events we are working with.

# %%
dmimgcalc ${c}.img,${c}.sum none frac_${c}.err op="imgout=((img1/img2)*sqrt((1.0/img1)+(1.0/img2)))" clob+

# %% [markdown]
# ## Plot branching ratios
#
# We can now plot the data using ChiPS.  We could also have read in the counts image above and renormalized it
# in chips via numpy, but go with what you know, right?

# %%
cat <<EOF | tee ploit_${c}.py | chips 

# Import from KJG's secret cache
import os
os.sys.path.insert( 0, "/data/da/Docs/scripts/dev/lib/python2.7/site-packages")
from chips_contrib.lut.color_curves import *
from chips_contrib.legend import *

# Load data
img = read_file("frac_${c}.img")
pix = img.get_image().values
err = read_file("frac_${c}.err").get_image().values

# '100' comes from bin size used to make images above
xlo = np.arange( pix.shape[0] )*100
xhi = xlo + 100

# Get list of grades w/ events
oo = np.sum(pix, axis=0)
fltgrades = list(set(np.arange(256)[oo>0]))
fltgrades.sort()

for gg in fltgrades: add_curve( (xlo+xhi)/2.0,  pix[:,gg], err[:,gg] )
color_curves("Colo_Coloured_sky_in")
set_curve("all", "symbol.style=none line.thickness=3")

limits(Y_AXIS, AUTO, 1 )
set_plot_xlabel("Energy [eV]")
set_plot_ylabel("Fraction of GOOD fltgrades")
set_plot_title("Grade Branching Ratios for chip ${c}")

# Add a legend
ll = Legend()
ll.label( map(str,fltgrades) )
set_current_frame(ll.frm)
reposition_frame(0.91, 0.6, 0.99, 0.8)
delete_region()
set_frame("border.visible=False")
set_current_frame("frm1")

# Save it.
print_window("ratios_${c}.png", 'export.clobber=True')
quit()
EOF

echo ""
display < ratios_${c}.png
# Out:
# -----------------------------------------
# Welcome to ChIPS: CXC's Plotting Package
# -----------------------------------------
# CIAO 4.8 ChIPS version 1 Thursday, December 3, 2015
#
# chips-1> chips-1> chips-2> chips-3> chips-4> chips-5> chips-6> chips-6> chips-7> chips-8> chips-9> chips-10> chips-10> chips-11> chips-12> chips-13> chips-13> chips-14> chips-15> chips-16> chips-17> chips-17> chips-18> chips-19> chips-20> chips-20> chips-21> chips-22> chips-23> chips-24> chips-24> chips-25> chips-26> chips-27> chips-28> chips-29> chips-30> chips-31> chips-32> chips-32> chips-33> chips-34>

# %% [markdown]
# There is a lot of good physics/structure going on here.  Note that events below 100 eV are very strongly affected by the choice of split and event thresholds
#
# Also grades 3 and 4 (left and right splits) almost entirely overlap.  If we were to further brake this dataset down by
# node, we would expect there to be a slightly more noticeable differance.

# %% [markdown]
# ## BI device
#
# Now let's replete for the BI chip

# %%
c="BI"
dmcopy "a1795_${c}_fltgrades.fits[grade=0,2,3,4,6][bin grade=0:7:1,energy=0:10000:100][opt type=i4]" ${c}.img clob+

dmimgproject ${c}.img ${c}.stats y clob+
dmimgreproject ${c}.stats"[cols y,sum]" ${c}.img ${c}.sum meth=close clob+
dmimgcalc ${c}.img ${c}.sum frac_${c}.img div clob+

dmimgcalc ${c}.img,${c}.sum none frac_${c}.err op="imgout=((img1/img2)*sqrt((1.0/img1)+(1.0/img2)))" clob+
cat <<EOF | tee ploit_${c}.py | chips 

# Import from KJG's secret cache
import os
os.sys.path.insert( 0, "/data/da/Docs/scripts/dev/lib/python2.7/site-packages")
from chips_contrib.lut.color_curves import *
from chips_contrib.legend import *

# Load data
img = read_file("frac_${c}.img")
pix = img.get_image().values
err = read_file("frac_${c}.err").get_image().values

# '100' comes from bin size used to make images above
xlo = np.arange( pix.shape[0] )*100
xhi = xlo + 100

# Get list of grades w/ events
oo = np.sum(pix, axis=0)
fltgrades = list(set(np.arange(256)[oo>0]))
fltgrades.sort()

for gg in fltgrades: add_curve( (xlo+xhi)/2.0,  pix[:,gg], err[:,gg] )
color_curves("Colo_Coloured_sky_in")
set_curve("all", "symbol.style=none line.thickness=3")

limits(Y_AXIS, AUTO, 1 )
set_plot_xlabel("Energy [eV]")
set_plot_ylabel("Fraction of GOOD fltgrades")
set_plot_title("Grade Branching Ratios for chip ${c}")

# Add a legend
ll = Legend()
ll.label( map(str,fltgrades) )
set_current_frame(ll.frm)
reposition_frame(0.91, 0.6, 0.99, 0.8)
delete_region()
set_frame("border.visible=False")
set_current_frame("frm1")

# Save it.
print_window("ratios_${c}.png", 'export.clobber=True')
quit()
EOF

echo ""
display < ratios_${c}.png
# Out:
# -----------------------------------------
# Welcome to ChIPS: CXC's Plotting Package
# -----------------------------------------
# CIAO 4.8 ChIPS version 1 Thursday, December 3, 2015
#
# chips-1> chips-1> chips-2> chips-3> chips-4> chips-5> chips-6> chips-6> chips-7> chips-8> chips-9> chips-10> chips-10> chips-11> chips-12> chips-13> chips-13> chips-14> chips-15> chips-16> chips-17> chips-17> chips-18> chips-19> chips-20> chips-20> chips-21> chips-22> chips-23> chips-24> chips-24> chips-25> chips-26> chips-27> chips-28> chips-29> chips-30> chips-31> chips-32> chips-32> chips-33> chips-34>

# %% [markdown]
# The distribution of events vs. energy for the BI chips is very different than for the FI chips.
